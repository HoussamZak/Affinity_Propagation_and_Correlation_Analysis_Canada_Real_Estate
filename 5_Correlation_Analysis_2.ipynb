# %% [markdown]
# We used https://fred.stlouisfed.org/ to download Canada's economic data that might play a role in Real Estate trends, price levels etc...
# One can also use https://tradingeconomics.com/canada/interest-rate.
#
# In the folder "Canadian Economy Data", you will find csv containing monthly data about unemployment, Central Bank real interest rates, CPI(inflation),
# M1 money supply, CAD-USD exchange rates.
#
# The goal is to develop a correlation matrix for between all data to help us in our featurs selection for the Machine Learning model I plan to make.
# Correlation as a statistical measure indicates the strength by which to two variables move together. Correlation can be positive/direct, negative/inverse or near 0, high correlation
# values -between a dependent variable and an independent variable- are of high significance in determining the output, finding high correlations between input and output values helps for in building more accurate and faster ML model. We must keep in mind that more features does not mean better accuracy, we shall avoid overfitting.
#
# We use Pearson Correlation coefficient -r- to measure how strong is the correlation in each pair of continiuous variables in our merged dataframe -hpi_and_economydata_df-.
# All data in each column are scaled and continuous, the samples of each variables are independent of each other and from reputable sources: statscan(Canadian Government) and
# stlouisfed.org. The correlation is calculated by dividing the covariance fo two variables by the product of their respective standard deviations.
#
# Correlation, r, ranges from -1 to 1 and is interpreted as follows:
# _the closer to 1, the stronger the correlation between two variables
#     _the close to 0, the weaker the correlation
#         _ r >= 0.75 is considered as a strong correlation and r <= -0.75 is considered as strong negative correlation (https://statisticsbyjim.com/basics/correlations/;
#         https://www.statology.org/what-is-a-strong-correlation/)
#
# +1 - Complete positive correlation
# +0.8 - Strong positive correlation
# +0.6 - Moderate positive correlation
# 0 - no correlation whatsoever
# -0.6 - Moderate negative correlation
# -0.8 - Strong negative correlation
# -1 - Complete negative correlation

# %%
import pandas as pd

# %%
# #Processing raw_material_index and building_material_indexes dataframes
# from distutils.command.build import build


# building_const_pi_df = pd.read_csv(r"C:\Users\hp\Desktop\Projects Coding\Affinity_Propagation_Canada_Real_Estate_Market\Real Estate Data\18100135-eng\BuildingConstructionPriceIndex_BCPI_18100135.csv")

# # type_of_buldings = building_const_pi_df["Type of building"].unique()
# # print(type_of_buldings)

# type_building_to_drop = ['Non-residential buildings [622]', 'Commercial buildings [62212]', 'Office building', 'Warehouse', 'Shopping centre', 'Industrial buildings [62211]', 
#                         'Factory', 'Bus depot with maintenance and repair facilities', 'Institutional buildings [62213]', 'School']

# #Removing rows that include strings in type_building_to_drop to maitain only buildings of interest.
# building_const_pi_df = building_const_pi_df[~building_const_pi_df['Type of building'].isin(['Non-residential buildings [622]', 'Commercial buildings [62212]', 'Office building', 'Warehouse', 'Shopping centre', 
#                         'Industrial buildings [62211]', 'Factory', 'Bus depot with maintenance and repair facilities', 'Institutional buildings [62213]', 'School'])]

# #Removing irrelevant GEO locations, we want to keep Cities
# building_const_pi_df = building_const_pi_df[~building_const_pi_df['GEO'].isin(['Eleven census metropolitan area composite'])]
# building_const_pi_df
# #Dropping irrelevant rows such as Symbols, status, vector...
# building_const_pi_df = building_const_pi_df.drop(columns=['DGUID','SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE','STATUS','SYMBOL','TERMINATED', 'UOM_ID','DECIMALS'], axis = 1)
# building_const_pi_df.head(100)


# building_const_pi_df.tail()

# # firstval = building_const_pi_df.VALUE.notna().idxmax()
# #First non NAN in VALUE column at index = 5410

# building_const_pi_df = building_const_pi_df.truncate(before = 5410)
# building_const_pi_df.reset_index()
# # building_const_pi_df.drop(columns=["index"], inplace = True, axis = 1)
# building_const_pi_df

# %%
# #Determining the different cities/GEO column
# locations = building_const_pi_df.GEO.unique()
# print(locations)

# # ['Halifax, Nova Scotia' , 'Moncton, New Brunswick' , 'Montréal, Quebec', 'Ottawa-Gatineau, Ontario part, Ontario/Quebec' , 'Toronto, Ontario' , 
# #  'Winnipeg, Manitoba' , 'Saskatoon, Saskatchewan' , 'Calgary, Alberta' , 'Edmonton, Alberta' , 'Vancouver, British Columbia', "St. John's, Newfoundland and Labrador"]

# %%
# type_of_buldings = building_const_pi_df["Type of building"].unique()
# print(type_of_buldings)

# %%
raw_material_price_index = pd.read_csv(r"C:\Users\hp\Desktop\Projects Coding\Affinity_Propagation_Canada_Real_Estate_Market\Real Estate Data\18100268-eng\Raw_Material_Price_Index-RMPI_18100268.csv")
raw_material_price_index.head()

# list_material = raw_material_price_index["North American Product Classification System (NAPCS)"].unique()
#Relevant materials in construction under "North American Product Classification System (NAPCS)" columns:
    #"Stone [16211]", "Logs and bolts [13111]", "Crushed stone [162112]", "Logs, pulpwood and other forestry products [131], 
    # "Logs, pulpwood, natural rubber and other forestry products [M41]"
# Out:
#   REF_DATE     GEO           DGUID  \
# 0  1981-01  Canada  2016A000011124
# 1  1981-01  Canada  2016A000011124
# 2  1981-01  Canada  2016A000011124
# 3  1981-01  Canada  2016A000011124
# 4  1981-01  Canada  2016A000011124
#
#   North American Product Classification System (NAPCS)                UOM  \
# 0          Total, Raw materials price indexes (RMPI)    Index, 202001=100
# 1                        Crude energy products [M51]    Index, 202001=100
# 2                     Conventional crude oil [14111]    Index, 202001=100
# 3                                  Natural gas [142]    Index, 202001=100
# 4                                  Hard coal [14411]    Index, 202001=100
#
#    UOM_ID SCALAR_FACTOR  SCALAR_ID       VECTOR  COORDINATE  VALUE STATUS  \
# 0     403         units          0  v1230998135         1.1   40.6    NaN
# 1     403         units          0  v1230998136         1.2   31.6    NaN
# 2     403         units          0  v1230998138         1.4   32.0    NaN
# 3     403         units          0  v1230998141         1.7   79.7    NaN
# 4     403         units          0  v1230998143         1.9   64.4    NaN
#
#    SYMBOL  TERMINATED  DECIMALS
# 0     NaN         NaN         1
# 1     NaN         NaN         1
# 2     NaN         NaN         1
# 3     NaN         NaN         1
# 4     NaN         NaN         1

# %%
cities_hpi_df = pd.read_csv(r"C:\Users\hp\Desktop\Projects Coding\Affinity_Propagation_Canada_Real_Estate_Market\Processed Data\cities_hpi_df.csv")

#Dropping Province HPI columns given the obvious correlation with the cities of the same provinces
cities_hpi_df = cities_hpi_df.drop(columns=["Unnamed: 0", "HPI_atlantic", "HPI_prairie_region"], axis = 1)

#If we don't want to maintain NAN values in our dataframe, hpi_df, many columns start from the top with NAN values let's check at which index the first float value is shown.
#We can find first index with float value by   hpu_df["HPI_sherbrooke_qc"].first_valid_index()
#Preview
cities_hpi_df.head()
# Out:
#   REF_DATE  HPI_nfland_labrador  HPI_charlottetown_pei  HPI_halifax_ns  \
# 0  1981-01                 37.5                    NaN             NaN
# 1  1981-02                 37.5                    NaN             NaN
# 2  1981-03                 37.5                    NaN             NaN
# 3  1981-04                 37.5                    NaN             NaN
# 4  1981-05                 37.7                    NaN             NaN
#
#    HPI_stjohn_fredericton_moncton  HPI_quebec_qc  HPI_sherbrooke_qc  \
# 0                            61.4           34.9                NaN
# 1                            62.1           35.4                NaN
# 2                            62.1           35.4                NaN
# 3                            62.1           35.7                NaN
# 4                            63.3           36.1                NaN
#
#    HPI_troisriv_qc  HPI_mtl_qc  HPI_ottawa_gatineau_qc  ...  HPI_guelph_ont  \
# 0              NaN        30.0                     NaN  ...             NaN
# 1              NaN        30.2                     NaN  ...             NaN
# 2              NaN        30.5                     NaN  ...             NaN
# 3              NaN        30.8                     NaN  ...             NaN
# 4              NaN        31.1                     NaN  ...             NaN
#
#    HPI_london_ont  HPI_windsor_ont  HPI_sudbury_ont  HPI_winnipeg_manitoba  \
# 0            27.0             64.9             54.6                   29.3
# 1            27.5             64.9             55.6                   29.7
# 2            28.2             64.1             55.6                   30.3
# 3            28.6             63.9             57.0                   30.5
# 4            28.6             63.9             57.0                   31.1
#
#    HPI_edmonton_alb  HPI_calgary_alb  HPI_victoria_bc  HPI_vancouver_bc  \
# 0              36.5             27.8            206.8              96.1
# 1              36.8             28.1            209.1              97.5
# 2              36.8             28.6            210.6              97.5
# 3              36.9             30.1            210.6              97.7
# 4              38.2             30.1            212.4              97.7
#
#    HPI_kelowna_bc
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# In the next cells, we load the economic data clean, organize them before storing them in dataframes.
# The dataframes are: unemployment_df, consumer_price_index_df, central_bank_interest_rate_df

# %%
#Unemployment dataframe
#We will drop all rows up to 1981-01-01

unemployment_df = pd.read_csv(r"C:\Users\hp\Desktop\Projects Coding\Affinity_Propagation_Canada_Real_Estate_Market\Canadian Economy Data\unemployment_LRUN64TTCAM156S.csv")
#
unemployment_df = unemployment_df.loc[(unemployment_df['DATE'] >= '1981-01-01' )]

#Renaming column for readable dataframe 
unemployment_df = unemployment_df.rename(columns={unemployment_df.columns[1]: 'unemployment_rate'})

#Renaming the date column to fit the date column in cities_hpi_df.
unemployment_df.rename(columns={'DATE':'REF_DATE'}, inplace = True)

#Let adjust the dataframe's DATE format to fit the YEAR-MONTH format in REF_DATE column in hp_df 
from datetime import datetime
unemployment_df['REF_DATE'] = pd.to_datetime(unemployment_df['REF_DATE']).dt.strftime('%Y-%m')    

#Resetting index without reassigning 
unemployment_df.reset_index(drop = True, inplace = True)
#Displaying dataframe with filtered date
unemployment_df.head()
# Out:
#   REF_DATE  unemployment_rate
# 0  1981-01                7.4
# 1  1981-02                7.4
# 2  1981-03                7.3
# 3  1981-04                7.1
# 4  1981-05                7.2

# %%
#CPI Consumer Price Index All Items Dataframe
#We will drop all rows up to 1981-01-01
consumer_price_index_df = pd.read_csv(r"C:\Users\hp\Desktop\Projects Coding\Affinity_Propagation_Canada_Real_Estate_Market\Canadian Economy Data\consumer_price_index_all_items_Canada_CPALTT01CAM659N.csv")

consumer_price_index_df = consumer_price_index_df.loc[(consumer_price_index_df['DATE'] >= '1981-01-01' )]

#Renaming column for readable dataframe 
consumer_price_index_df = consumer_price_index_df.rename(columns={consumer_price_index_df.columns[1]: 'CPI_inflation'})

#Renaming the date column to fit the date column in cities_hpi_df.
consumer_price_index_df.rename(columns={'DATE':'REF_DATE'}, inplace = True)

#Let adjust the dataframe's DATE format to fit the YEAR-MONTH format in REF_DATE column in hp_df 
consumer_price_index_df['REF_DATE'] = pd.to_datetime(consumer_price_index_df['REF_DATE']).dt.strftime('%Y-%m') 

#Resetting index without reassigning 
consumer_price_index_df.reset_index(drop = True, inplace = True)
#Displaying dataframe with filtered date
consumer_price_index_df.head()
# Out:
#   REF_DATE  CPI_inflation
# 0  1981-01      12.200957
# 1  1981-02      12.056738
# 2  1981-03      12.676056
# 3  1981-04      12.587413
# 4  1981-05      12.211982

# %%
#Interest Rate Central Bank dataframe
#We will drop all rows up to 1981-01-01
central_bank_interest_rate_df = pd.read_csv(r"C:\Users\hp\Desktop\Projects Coding\Affinity_Propagation_Canada_Real_Estate_Market\Canadian Economy Data\interest_rate_Central_Bank_CanadaIRSTCB01CAM156N.csv")

central_bank_interest_rate_df = central_bank_interest_rate_df.loc[(central_bank_interest_rate_df['DATE'] >= '1981-01-01' )]

#Renaming column for readable dataframe 
central_bank_interest_rate_df = central_bank_interest_rate_df.rename(columns={central_bank_interest_rate_df.columns[1]: 'Interest_Rate_Central_Bank'})

#Renaming the date column to fit the date column in cities_hpi_df.
central_bank_interest_rate_df.rename(columns={'DATE':'REF_DATE'}, inplace = True)

#Let adjust the dataframe's DATE format to fit the YEAR-MONTH format in REF_DATE column in hp_df 
central_bank_interest_rate_df['REF_DATE'] = pd.to_datetime(central_bank_interest_rate_df['REF_DATE']).dt.strftime('%Y-%m') 


#Resetting index without reassigning 
central_bank_interest_rate_df.reset_index(drop = True, inplace = True)
#Displaying dataframe with filtered date
central_bank_interest_rate_df.tail()
# Out:
#     REF_DATE  Interest_Rate_Central_Bank
# 495  2022-04                        1.25
# 496  2022-05                        1.25
# 497  2022-06                        1.75
# 498  2022-07                        2.75
# 499  2022-08                        2.75

# %%
"""With the economical dataframes ready, central_bank_interest_rate_df, consumer_price_index_df and unemployment_rate_df, let's merge their data 
on DATE column with cities_hpi_df before our Correlation Matrix!"""

from functools import reduce

dataframes2 = [cities_hpi_df, central_bank_interest_rate_df, consumer_price_index_df, unemployment_df]

#Merging dataframes2 on REF_DATE
hpi_and_economydata_df = reduce(lambda left, right: pd.merge(left, right, on = 'REF_DATE'), dataframes2)

#Saving dataframe as csv
hpi_and_economydata_df.to_csv(r"C:\Users\hp\Desktop\Projects Coding\Affinity_Propagation_Canada_Real_Estate_Market\Processed Data\hpi_and_economydata_df.csv")

#Previewing
hpi_and_economydata_df.tail()
# Out:
#     REF_DATE  HPI_nfland_labrador  HPI_charlottetown_pei  HPI_halifax_ns  \
# 494  2022-03                106.7                  125.5           123.9
# 495  2022-04                106.7                  125.5           123.9
# 496  2022-05                106.7                  125.5           127.5
# 497  2022-06                107.4                  126.9           127.5
# 498  2022-07                107.4                  127.3           127.5
#
#      HPI_stjohn_fredericton_moncton  HPI_quebec_qc  HPI_sherbrooke_qc  \
# 494                           119.1          131.3              112.4
# 495                           121.1          131.3              113.1
# 496                           121.1          132.6              113.1
# 497                           121.1          133.3              113.1
# 498                           121.1          133.3              113.1
#
#      HPI_troisriv_qc  HPI_mtl_qc  HPI_ottawa_gatineau_qc  ...  \
# 494            112.6       160.0                   120.1  ...
# 495            112.6       159.2                   120.1  ...
# 496            112.6       161.1                   120.5  ...
# 497            112.6       160.9                   120.5  ...
# 498            112.6       160.6                   120.5  ...
#
#      HPI_sudbury_ont  HPI_winnipeg_manitoba  HPI_edmonton_alb  \
# 494            121.7                  155.0             111.3
# 495            121.7                  156.9             112.0
# 496            122.3                  158.6             113.5
# 497            122.5                  158.6             113.6
# 498            122.5                  158.6             113.2
#
#      HPI_calgary_alb  HPI_victoria_bc  HPI_vancouver_bc  HPI_kelowna_bc  \
# 494            128.3            132.1             127.0           126.3
# 495            131.1            132.1             127.2           126.3
# 496            133.4            132.1             127.2           128.3
# 497            133.6            132.1             127.2           128.3
# 498            133.2            132.1             127.6           128.4
#
#      Interest_Rate_Central_Bank  CPI_inflation  unemployment_rate
# 494                        0.75       6.661891                5.2
# 495                        1.25       6.771205                5.1
# 496                        1.25       7.730496                5.0
# 497                        1.75       8.132956                5.1
# 498                        2.75       7.589599                5.0
#
# [5 rows x 27 columns]

# %%
import numpy as np 
import seaborn as sns

from matplotlib import pyplot as plt
from pandas.plotting import register_matplotlib_converters

# import matplotlib.dates as mdates
# import requests
# import json

# %%
# list_length = hpi_and_economydata_df.shape[1]
ncols = 10
# nrows = int(round(list_length / ncols, 0))
# height = list_length / 3 if list_length > 30 else 16

# fig, axs = plt.subplots(nrows = nrows, ncols = ncols, sharex = True, sharey = True, figsize=(20, height))

# for i, ax in enumerate(fig.axes):
#     if i < list_length:
#         sns.lineplot(data = hpi_and_economydata_df, x = hpi_and_economydata_df.index, y = hpi_and_economydata_df.iloc[:, i], ax = ax)
#         ax.set_title(hpi_and_economydata_df.columns[i])
#         ax.tick_params(labelrotation = 45)

# plt.show()

# %%
#Diagonal Matrix

sns.set(style = "white")

#Column titles
col_list = hpi_and_economydata_df.columns


# #Matrix correlation
df = pd.DataFrame(hpi_and_economydata_df, columns = col_list)
corr = hpi_and_economydata_df.corr()
corr
# Out:
#                                 HPI_nfland_labrador  HPI_charlottetown_pei  \
# HPI_nfland_labrador                        1.000000               0.809178
# HPI_charlottetown_pei                      0.809178               1.000000
# HPI_halifax_ns                             0.967365               0.915595
# HPI_stjohn_fredericton_moncton             0.913697               0.938158
# HPI_quebec_qc                              0.956336               0.931131
# HPI_sherbrooke_qc                          0.726469               0.857638
# HPI_troisriv_qc                            0.814820               0.949985
# HPI_mtl_qc                                 0.939378               0.960976
# HPI_ottawa_gatineau_qc                     0.750806               0.934678
# HPI_ottawa_gatineau_ont                    0.908960               0.962205
# HPI_oshawa_ont                             0.929323               0.972884
# HPI_toronto_ont                            0.943705               0.840802
# HPI_hamilton_ont                           0.947803               0.886894
# HPI_guelph_ont                             0.857722               0.982178
# HPI_london_ont                             0.931633               0.923558
# HPI_windsor_ont                            0.678066               0.756213
# HPI_sudbury_ont                            0.867391               0.922163
# HPI_winnipeg_manitoba                      0.952084               0.921530
# HPI_edmonton_alb                           0.943596               0.810671
# HPI_calgary_alb                            0.956058               0.865987
# HPI_victoria_bc                           -0.745164              -0.083705
# HPI_vancouver_bc                           0.700836               0.876443
# HPI_kelowna_bc                             0.881786               0.985258
# Interest_Rate_Central_Bank                -0.794187              -0.648842
# CPI_inflation                             -0.423126               0.360684
# unemployment_rate                         -0.551424              -0.376807
#
#                                 HPI_halifax_ns  \
# HPI_nfland_labrador                   0.967365
# HPI_charlottetown_pei                 0.915595
# HPI_halifax_ns                        1.000000
# HPI_stjohn_fredericton_moncton        0.944111
# HPI_quebec_qc                         0.983846
# HPI_sherbrooke_qc                     0.875349
# HPI_troisriv_qc                       0.975187
# HPI_mtl_qc                            0.984877
# HPI_ottawa_gatineau_qc                0.963947
# HPI_ottawa_gatineau_ont               0.966878
# HPI_oshawa_ont                        0.951378
# HPI_toronto_ont                       0.961899
# HPI_hamilton_ont                      0.982082
# HPI_guelph_ont                        0.992331
# HPI_london_ont                        0.974222
# HPI_windsor_ont                       0.757345
# HPI_sudbury_ont                       0.897312
# HPI_winnipeg_manitoba                 0.985872
# HPI_edmonton_alb                      0.938498
# HPI_calgary_alb                       0.970069
# HPI_victoria_bc                      -0.717476
# HPI_vancouver_bc                      0.708448
# HPI_kelowna_bc                        0.982344
# Interest_Rate_Central_Bank           -0.817482
# CPI_inflation                        -0.251645
# unemployment_rate                    -0.600490
#
#                                 HPI_stjohn_fredericton_moncton  HPI_quebec_qc  \
# HPI_nfland_labrador                                   0.913697       0.956336
# HPI_charlottetown_pei                                 0.938158       0.931131
# HPI_halifax_ns                                        0.944111       0.983846
# HPI_stjohn_fredericton_moncton                        1.000000       0.958409
# HPI_quebec_qc                                         0.958409       1.000000
# HPI_sherbrooke_qc                                     0.926793       0.880470
# HPI_troisriv_qc                                       0.929422       0.925072
# HPI_mtl_qc                                            0.950196       0.982006
# HPI_ottawa_gatineau_qc                                0.906686       0.891594
# HPI_ottawa_gatineau_ont                               0.916849       0.954799
# HPI_oshawa_ont                                        0.963715       0.975273
# HPI_toronto_ont                                       0.926299       0.950485
# HPI_hamilton_ont                                      0.946644       0.977489
# HPI_guelph_ont                                        0.948933       0.953755
# HPI_london_ont                                        0.956331       0.969562
# HPI_windsor_ont                                       0.847244       0.827801
# HPI_sudbury_ont                                       0.957690       0.929216
# HPI_winnipeg_manitoba                                 0.919981       0.956141
# HPI_edmonton_alb                                      0.865024       0.944951
# HPI_calgary_alb                                       0.879345       0.954882
# HPI_victoria_bc                                      -0.686297      -0.767053
# HPI_vancouver_bc                                      0.783282       0.696730
# HPI_kelowna_bc                                        0.983606       0.979131
# Interest_Rate_Central_Bank                           -0.783221      -0.841574
# CPI_inflation                                        -0.512909      -0.483681
# unemployment_rate                                    -0.553292      -0.637307
#
#                                 HPI_sherbrooke_qc  HPI_troisriv_qc  \
# HPI_nfland_labrador                      0.726469         0.814820
# HPI_charlottetown_pei                    0.857638         0.949985
# HPI_halifax_ns                           0.875349         0.975187
# HPI_stjohn_fredericton_moncton           0.926793         0.929422
# HPI_quebec_qc                            0.880470         0.925072
# HPI_sherbrooke_qc                        1.000000         0.889817
# HPI_troisriv_qc                          0.889817         1.000000
# HPI_mtl_qc                               0.926950         0.972529
# HPI_ottawa_gatineau_qc                   0.873268         0.987701
# HPI_ottawa_gatineau_ont                  0.912617         0.984348
# HPI_oshawa_ont                           0.824136         0.904758
# HPI_toronto_ont                          0.787743         0.818865
# HPI_hamilton_ont                         0.822952         0.977780
# HPI_guelph_ont                           0.850782         0.978718
# HPI_london_ont                           0.928900         0.944487
# HPI_windsor_ont                          0.911874         0.944274
# HPI_sudbury_ont                          0.846643         0.928244
# HPI_winnipeg_manitoba                    0.917285         0.901227
# HPI_edmonton_alb                         0.726256         0.639435
# HPI_calgary_alb                          0.806465         0.697039
# HPI_victoria_bc                          0.871656         0.907705
# HPI_vancouver_bc                         0.801522         0.862496
# HPI_kelowna_bc                           0.887305         0.939921
# Interest_Rate_Central_Bank              -0.161513        -0.400469
# CPI_inflation                            0.759187         0.670023
# unemployment_rate                       -0.017448         0.059893
#
#                                 HPI_mtl_qc  HPI_ottawa_gatineau_qc  \
# HPI_nfland_labrador               0.939378                0.750806
# HPI_charlottetown_pei             0.960976                0.934678
# HPI_halifax_ns                    0.984877                0.963947
# HPI_stjohn_fredericton_moncton    0.950196                0.906686
# HPI_quebec_qc                     0.982006                0.891594
# HPI_sherbrooke_qc                 0.926950                0.873268
# HPI_troisriv_qc                   0.972529                0.987701
# HPI_mtl_qc                        1.000000                0.965153
# HPI_ottawa_gatineau_qc            0.965153                1.000000
# HPI_ottawa_gatineau_ont           0.990113                0.980687
# HPI_oshawa_ont                    0.944377                0.874393
# HPI_toronto_ont                   0.959235                0.773473
# HPI_hamilton_ont                  0.981322                0.972669
# HPI_guelph_ont                    0.977605                0.971754
# HPI_london_ont                    0.991051                0.936685
# HPI_windsor_ont                   0.847303                0.927468
# HPI_sudbury_ont                   0.919945                0.916955
# HPI_winnipeg_manitoba             0.982833                0.870625
# HPI_edmonton_alb                  0.915208                0.569565
# HPI_calgary_alb                   0.944967                0.636506
# HPI_victoria_bc                  -0.708017                0.873307
# HPI_vancouver_bc                  0.738674                0.829877
# HPI_kelowna_bc                    0.979490                0.924931
# Interest_Rate_Central_Bank       -0.792420               -0.418068
# CPI_inflation                    -0.394143                0.615413
# unemployment_rate                -0.606946                0.143311
#
#                                 HPI_ottawa_gatineau_ont  ...  HPI_sudbury_ont  \
# HPI_nfland_labrador                            0.908960  ...         0.867391
# HPI_charlottetown_pei                          0.962205  ...         0.922163
# HPI_halifax_ns                                 0.966878  ...         0.897312
# HPI_stjohn_fredericton_moncton                 0.916849  ...         0.957690
# HPI_quebec_qc                                  0.954799  ...         0.929216
# HPI_sherbrooke_qc                              0.912617  ...         0.846643
# HPI_troisriv_qc                                0.984348  ...         0.928244
# HPI_mtl_qc                                     0.990113  ...         0.919945
# HPI_ottawa_gatineau_qc                         0.980687  ...         0.916955
# HPI_ottawa_gatineau_ont                        1.000000  ...         0.875269
# HPI_oshawa_ont                                 0.936066  ...         0.962117
# HPI_toronto_ont                                0.936342  ...         0.878201
# HPI_hamilton_ont                               0.958345  ...         0.909027
# HPI_guelph_ont                                 0.986295  ...         0.967922
# HPI_london_ont                                 0.976128  ...         0.930843
# HPI_windsor_ont                                0.825134  ...         0.903645
# HPI_sudbury_ont                                0.875269  ...         1.000000
# HPI_winnipeg_manitoba                          0.977155  ...         0.878839
# HPI_edmonton_alb                               0.880764  ...         0.830315
# HPI_calgary_alb                                0.920384  ...         0.836683
# HPI_victoria_bc                               -0.645759  ...        -0.725481
# HPI_vancouver_bc                               0.732585  ...         0.732252
# HPI_kelowna_bc                                 0.975206  ...         0.979802
# Interest_Rate_Central_Bank                    -0.746985  ...        -0.810052
# CPI_inflation                                 -0.321030  ...        -0.561907
# unemployment_rate                             -0.569082  ...        -0.532316
#
#                                 HPI_winnipeg_manitoba  HPI_edmonton_alb  \
# HPI_nfland_labrador                          0.952084          0.943596
# HPI_charlottetown_pei                        0.921530          0.810671
# HPI_halifax_ns                               0.985872          0.938498
# HPI_stjohn_fredericton_moncton               0.919981          0.865024
# HPI_quebec_qc                                0.956141          0.944951
# HPI_sherbrooke_qc                            0.917285          0.726256
# HPI_troisriv_qc                              0.901227          0.639435
# HPI_mtl_qc                                   0.982833          0.915208
# HPI_ottawa_gatineau_qc                       0.870625          0.569565
# HPI_ottawa_gatineau_ont                      0.977155          0.880764
# HPI_oshawa_ont                               0.961659          0.835842
# HPI_toronto_ont                              0.968435          0.888636
# HPI_hamilton_ont                             0.971216          0.920612
# HPI_guelph_ont                               0.926306          0.698265
# HPI_london_ont                               0.981328          0.892471
# HPI_windsor_ont                              0.782269          0.669785
# HPI_sudbury_ont                              0.878839          0.830315
# HPI_winnipeg_manitoba                        1.000000          0.904116
# HPI_edmonton_alb                             0.904116          1.000000
# HPI_calgary_alb                              0.951505          0.983377
# HPI_victoria_bc                             -0.686304         -0.739067
# HPI_vancouver_bc                             0.743086          0.657293
# HPI_kelowna_bc                               0.978597          0.811972
# Interest_Rate_Central_Bank                  -0.753400         -0.783539
# CPI_inflation                               -0.331484         -0.424624
# unemployment_rate                           -0.585990         -0.643418
#
#                                 HPI_calgary_alb  HPI_victoria_bc  \
# HPI_nfland_labrador                    0.956058        -0.745164
# HPI_charlottetown_pei                  0.865987        -0.083705
# HPI_halifax_ns                         0.970069        -0.717476
# HPI_stjohn_fredericton_moncton         0.879345        -0.686297
# HPI_quebec_qc                          0.954882        -0.767053
# HPI_sherbrooke_qc                      0.806465         0.871656
# HPI_troisriv_qc                        0.697039         0.907705
# HPI_mtl_qc                             0.944967        -0.708017
# HPI_ottawa_gatineau_qc                 0.636506         0.873307
# HPI_ottawa_gatineau_ont                0.920384        -0.645759
# HPI_oshawa_ont                         0.864765         0.982443
# HPI_toronto_ont                        0.931553        -0.703881
# HPI_hamilton_ont                       0.949417        -0.734100
# HPI_guelph_ont                         0.742364         0.943464
# HPI_london_ont                         0.929464        -0.698198
# HPI_windsor_ont                        0.700479        -0.668619
# HPI_sudbury_ont                        0.836683        -0.725481
# HPI_winnipeg_manitoba                  0.951505        -0.686304
# HPI_edmonton_alb                       0.983377        -0.739067
# HPI_calgary_alb                        1.000000        -0.719648
# HPI_victoria_bc                       -0.719648         1.000000
# HPI_vancouver_bc                       0.686573        -0.188585
# HPI_kelowna_bc                         0.856863         0.979042
# Interest_Rate_Central_Bank            -0.759734         0.890748
# CPI_inflation                         -0.362782         0.695082
# unemployment_rate                     -0.655783         0.590197
#
#                                 HPI_vancouver_bc  HPI_kelowna_bc  \
# HPI_nfland_labrador                     0.700836        0.881786
# HPI_charlottetown_pei                   0.876443        0.985258
# HPI_halifax_ns                          0.708448        0.982344
# HPI_stjohn_fredericton_moncton          0.783282        0.983606
# HPI_quebec_qc                           0.696730        0.979131
# HPI_sherbrooke_qc                       0.801522        0.887305
# HPI_troisriv_qc                         0.862496        0.939921
# HPI_mtl_qc                              0.738674        0.979490
# HPI_ottawa_gatineau_qc                  0.829877        0.924931
# HPI_ottawa_gatineau_ont                 0.732585        0.975206
# HPI_oshawa_ont                          0.940695        0.970756
# HPI_toronto_ont                         0.749377        0.928978
# HPI_hamilton_ont                        0.738816        0.942500
# HPI_guelph_ont                          0.901357        0.971559
# HPI_london_ont                          0.775303        0.973780
# HPI_windsor_ont                         0.595714        0.989930
# HPI_sudbury_ont                         0.732252        0.979802
# HPI_winnipeg_manitoba                   0.743086        0.978597
# HPI_edmonton_alb                        0.657293        0.811972
# HPI_calgary_alb                         0.686573        0.856863
# HPI_victoria_bc                        -0.188585        0.979042
# HPI_vancouver_bc                        1.000000        0.947277
# HPI_kelowna_bc                          0.947277        1.000000
# Interest_Rate_Central_Bank             -0.359249       -0.284587
# CPI_inflation                          -0.113973        0.835379
# unemployment_rate                      -0.336193       -0.111443
#
#                                 Interest_Rate_Central_Bank  CPI_inflation  \
# HPI_nfland_labrador                              -0.794187      -0.423126
# HPI_charlottetown_pei                            -0.648842       0.360684
# HPI_halifax_ns                                   -0.817482      -0.251645
# HPI_stjohn_fredericton_moncton                   -0.783221      -0.512909
# HPI_quebec_qc                                    -0.841574      -0.483681
# HPI_sherbrooke_qc                                -0.161513       0.759187
# HPI_troisriv_qc                                  -0.400469       0.670023
# HPI_mtl_qc                                       -0.792420      -0.394143
# HPI_ottawa_gatineau_qc                           -0.418068       0.615413
# HPI_ottawa_gatineau_ont                          -0.746985      -0.321030
# HPI_oshawa_ont                                   -0.353812       0.835481
# HPI_toronto_ont                                  -0.734949      -0.374772
# HPI_hamilton_ont                                 -0.788384      -0.434591
# HPI_guelph_ont                                   -0.435924       0.710754
# HPI_london_ont                                   -0.776819      -0.402480
# HPI_windsor_ont                                  -0.729991      -0.476128
# HPI_sudbury_ont                                  -0.810052      -0.561907
# HPI_winnipeg_manitoba                            -0.753400      -0.331484
# HPI_edmonton_alb                                 -0.783539      -0.424624
# HPI_calgary_alb                                  -0.759734      -0.362782
# HPI_victoria_bc                                   0.890748       0.695082
# HPI_vancouver_bc                                 -0.359249      -0.113973
# HPI_kelowna_bc                                   -0.284587       0.835379
# Interest_Rate_Central_Bank                        1.000000       0.753635
# CPI_inflation                                     0.753635       1.000000
# unemployment_rate                                 0.435034       0.169752
#
#                                 unemployment_rate
# HPI_nfland_labrador                     -0.551424
# HPI_charlottetown_pei                   -0.376807
# HPI_halifax_ns                          -0.600490
# HPI_stjohn_fredericton_moncton          -0.553292
# HPI_quebec_qc                           -0.637307
# HPI_sherbrooke_qc                       -0.017448
# HPI_troisriv_qc                          0.059893
# HPI_mtl_qc                              -0.606946
# HPI_ottawa_gatineau_qc                   0.143311
# HPI_ottawa_gatineau_ont                 -0.569082
# HPI_oshawa_ont                          -0.172206
# HPI_toronto_ont                         -0.639646
# HPI_hamilton_ont                        -0.639196
# HPI_guelph_ont                           0.025243
# HPI_london_ont                          -0.596675
# HPI_windsor_ont                         -0.595375
# HPI_sudbury_ont                         -0.532316
# HPI_winnipeg_manitoba                   -0.585990
# HPI_edmonton_alb                        -0.643418
# HPI_calgary_alb                         -0.655783
# HPI_victoria_bc                          0.590197
# HPI_vancouver_bc                        -0.336193
# HPI_kelowna_bc                          -0.111443
# Interest_Rate_Central_Bank               0.435034
# CPI_inflation                            0.169752
# unemployment_rate                        1.000000
#
# [26 rows x 26 columns]

# %%
#Visualizing the Correlation Matrix with colors, HeatMap, showing the strength
mask = np.triu(np.ones_like(corr, dtype = np.bool))

f, ax = plt.subplots(figsize=(14,10))

#Heatmap colors
cmap = "RdBu"

sns.heatmap(
    corr,
    mask = mask,
    cmap = cmap,
    center = 0,
    square = True,
    linewidths = 0.5, 
    cbar_kws ={"shrink": 0.5},
)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_20900\3028599167.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(corr, dtype = np.bool))
# <AxesSubplot:>

# %%
#Filtering values in our correlation Matrix to keep only strong correlation values.
 
dfCorr = hpi_and_economydata_df.corr()
filteredDf = dfCorr[((dfCorr >= .75) | (dfCorr <= -.75)) & (dfCorr !=1.000)]
plt.figure(figsize=(20,10))
sns.heatmap(filteredDf, annot=True, cmap="RdBu")
plt.show()

# %%
# loading the CSV with HPI , Economy data and Building construction price indexes
from matplotlib import pyplot

df2 = pd.read_csv(r"C:\Users\hp\Desktop\Projects Coding\Affinity_Propagation_Canada_Real_Estate_Market\Processed Data\hpi_econo_and_constmaterial_merged_df.csv")
# Dropping useless columns
del df2["Unnamed: 0"]
del df2["REF_DATE"]

correlation = df2.corr()

# Plotting figures & heatmap
plt.figure(figsize = (20, 15))
plt.title("HPI, Econ.metric and building construction price indexes Correlation")
sns.heatmap(correlation, vmax = 1, square = True, annot = True, cmap = 'cubehelix')
# Out:
# <AxesSubplot:title={'center':'HPI, Econ.metric and building construction price indexes Correlation'}>

# %%
correlation.columns
# Out:
# Index(['stone_VALUE', 'crushedStone_VALUE', 'logsbolts_VALUE',
#        'ironOres_concentrates_VALUE', 'HPI_nfland_labrador',
#        'HPI_charlottetown_pei', 'HPI_halifax_ns',
#        'HPI_stjohn_fredericton_moncton', 'HPI_quebec_qc', 'HPI_sherbrooke_qc',
#        'HPI_troisriv_qc', 'HPI_mtl_qc', 'HPI_ottawa_gatineau_qc',
#        'HPI_ottawa_gatineau_ont', 'HPI_oshawa_ont', 'HPI_toronto_ont',
#        'HPI_hamilton_ont', 'HPI_guelph_ont', 'HPI_london_ont',
#        'HPI_windsor_ont', 'HPI_sudbury_ont', 'HPI_winnipeg_manitoba',
#        'HPI_edmonton_alb', 'HPI_calgary_alb', 'HPI_victoria_bc',
#        'HPI_vancouver_bc', 'HPI_kelowna_bc', 'Interest_Rate_Central_Bank',
#        'CPI_inflation', 'unemployment_rate'],
#       dtype='object')
